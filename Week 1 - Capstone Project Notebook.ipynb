# %% [markdown]
# # Week 1: Capstone Project Notebook
#
# Welcome to my repository for my Coursera IBM Data Science Certification Course "Data Science Capstone Project". This notebook, and others like it in this repository, will mainly be used for the aforementioned course.
#
# Here is some simple code:

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
